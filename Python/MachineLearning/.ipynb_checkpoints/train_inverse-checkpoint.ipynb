# %%
import tensorflow as tf
from keras import layers
from keras import models
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2022-02-21 16:28:56.469299: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-21 16:28:56.469331: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
square = models.Sequential()
#n_zernike = 8
#n_actuators = 51
square.add(layers.Dense(1, activation='linear', input_shape=[1]))
square.add(layers.Dense(64, activation='relu', kernel_initializer='normal'))
square.add(layers.Dense(64, activation='relu'))
square.add(layers.Dense(1, activation='linear'))
square.compile(loss="mse", optimizer='adam')

# %%
x = np.linspace(0.1, 5, 2000).reshape(-1, 1)
f = lambda x: np.sin(np.pi*x)/(np.pi*x)
y = f(x)
print(np.min(x), np.max(x))

# %%
hist = square.fit(y, x, batch_size=10, epochs=50)

# %%
inp = np.linspace(0, 5, 2000)
res = square(inp.reshape(-1, 1))

# %%
# %matplotlib notebook
plt.plot(inp, res)
plt.plot(inp, f(inp))
# Out:
# <img src="data:image/png;base64,..." width="640">
# /tmp/ipykernel_381548/2278988468.py:2: RuntimeWarning: invalid value encountered in true_divide
#   f = lambda x: np.sin(np.pi*x)/(np.pi*x)

# %%
inv = models.Sequential()
#n_zernike = 8
#n_actuators = 51


inv.add(layers.Dense(1))
inv.add(layers.Dense(1024, activation='relu', kernel_initializer='normal'))
inv.add(layers.Dropout(0.5))
inv.add(layers.Dense(512, activation='relu'))
inv.add(layers.Dropout(0.5))
inv.add(layers.Dense(128))
inv.add(layers.Dense(1, activation="linear", kernel_initializer="normal"))

inv.compile(loss="mse", optimizer='adam')

# %%
x = np.random.uniform(0, 5)
