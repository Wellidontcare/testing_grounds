# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook
theta = np.linspace(0, np.pi, 100)
phi = np.linspace(0, 2*np.pi, 100)
theta, phi = np.meshgrid(th, ph)
r1 = lambda theta, phi: np.sqrt(5/(16**np.pi))*(3*np.cos(theta)**2 - 1)
r2 = lambda theta, phi: np.sqrt(15/(8**np.pi))*np.exp(-1j*phi)*np.sin(theta)*np.cos(theta)






x = np.imag(r2(theta, phi)) * np.sin(theta)*np.cos(phi)
y = np.imag(r2(theta, phi)) * np.sin(theta)*np.sin(phi)
z = np.imag(r2(theta, phi)) * np.cos(theta)


fig = plt.figure(1)
ax = fig.add_subplot(projection='3d')
ax.plot_surface(x, y, z)
x = np.real(r2(theta, phi)) * np.sin(theta)*np.cos(phi)
y = np.real(r2(theta, phi)) * np.sin(theta)*np.sin(phi)
z = np.real(r2(theta, phi)) * np.cos(theta)
ax.plot_surface(x, y, z)
x = np.abs(r2(theta, phi))**2 * np.sin(theta)*np.cos(phi)
y = np.abs(r2(theta, phi))**2 * np.sin(theta)*np.sin(phi)
z = np.abs(r2(theta, phi))**2 * np.cos(theta)
ax.plot_surface(x, y, z)
# Out:
# <img src="data:image/png;base64,..." width="640">
