# %%
import sympy as sp
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="darkgrid")

# %%
x, u = sp.symbols('x, u', real=True)

# %%
f = 3**x - 3**(0.5*(x+4)) + 20

# %%
u_s = 3**(0.5*x)
f_sub = f.factor().subs(u_s, u).simplify()
display(f_sub)
# Out:
# -9.0*u + 1.0*u**2.0 + 20.0

# %%
u1, u2 = sp.solve(f_sub, u)
display(u1)
# Out:
# 4.00000000000000

# %%
x1 = sp.solveset(sp.Eq(u1, u_s), x, domain=sp.S.Reals)
x2 = sp.solveset(sp.Eq(u2, u_s), x, domain=sp.S.Reals)
display(x1)
display(x2)
display(sp.Eq(u1, u_s))
# Out:
# {2.77258872223978/log(3)}
# {3.2188758248682/log(3)}
# Eq(4.0, 3**(0.5*x))

# %%
sp.solveset(sp.expand_power_base(f), x, domain=sp.S.Reals)
# Out:
# ConditionSet(x, Eq(3**x - 3**(0.5*x + 2.0) + 20, 0), Reals)

# %%
display(sp.solveset(f.rewrite(sp.exp)))
# Out:
# ConditionSet(x, Eq(0.45*3**(0.5*x) - 0.05*3**x - 1.0, 0), Complexes)

# %%
sp.nonlinsolve(f)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_130282/2763627142.py in <module>
# ----> 1 sp.nonlinsolve(f, x)
#
# ~/.local/lib/python3.9/site-packages/sympy/solvers/solveset.py in nonlinsolve(system, *symbols)
#    3640         raise IndexError(filldedent(msg))
#    3641
# -> 3642     system, symbols, swap = recast_to_symbols(system, symbols)
#    3643     if swap:
#    3644         soln = nonlinsolve(system, symbols)
#
# ~/.local/lib/python3.9/site-packages/sympy/solvers/solvers.py in recast_to_symbols(eqs, symbols)
#      90     """
#      91     if not iterable(eqs) and iterable(symbols):
# ---> 92         raise ValueError('Both eqs and symbols must be iterable')
#      93     new_symbols = list(symbols)
#      94     swap_sym = {}
#
# ValueError: Both eqs and symbols must be iterable

# %%
# %matplotlib notebook
sp.var("x, y")

p = sp.plotting.plot_implicit(sp.Eq(x**2 + y**2, 1), aspect_ratio=(1, 1), grid=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure(2)
x = np.linspace(-1, 1)
y = x.copy()
plt.plot(x, y)
plt.title("Test")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Test')
