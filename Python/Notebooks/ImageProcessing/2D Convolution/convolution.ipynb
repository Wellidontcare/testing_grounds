# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-20, 20, 1001)
y = np.sqrt(abs(x)+1)
plt.grid(True)
plt.plot(x, y)
y = np.convolve(y, y, 'same') / (np.sum(y)+1)
plt.plot(x, y)
y = np.convolve(y, y, 'same') / (np.sum(y)+1)
plt.plot(x, y)
y = np.convolve(y, y, 'same') / (np.sum(y)+1)
plt.plot(x, y)
y = np.convolve(y, y, 'same') / (np.sum(y)+1)
plt.plot(x, y)
